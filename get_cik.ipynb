# %%
import pandas as pd

def get_cik():
    ticker = pd.read_csv('ticker.txt', delimiter='\t', header=None)
    dow30 = pd.read_excel('dow30_complete.xlsx', index_col=0)

    dow30 = dow30.loc[:,['from', 'thru', 'co_conm', 'co_tic']]
    dow30['thru'] = dow30['thru'].replace('.','20201116')
    dow30['co_tic'] = dow30['co_tic'].apply(lambda x: str.lower(x))
    ticker = ticker.rename(columns={0:'co_tic',1:'cik'})

    dow30 = dow30.merge(ticker, how='left', on='co_tic')

    dow30['start_y'] = dow30['from'].apply(lambda x: str(x)[:4])
    dow30['end_y'] = dow30['thru'].apply(lambda x: str(x)[:4])

    dow30['start_q'] = dow30['from'].apply(lambda x: (int(str(x)[4:6])-1)//3+1)
    dow30['end_q'] = dow30['thru'].apply(lambda x: (int(str(x)[4:6])-1)//3+1)

    dow30 = dow30.loc[:,['start_y', 'start_q', 'end_y', 'end_q','cik']]
    return dow30

# %%
dow30
# Out:
#    start_y  start_q end_y  end_q      cik
# 0     1907        4  2018      2    40545
# 1     1915        1  2009      2  1467858
# 2     1928        4  2020      3    34088
# 3     1932        2  2020      4    21344
# 4     1932        2  2020      4    51143
# 5     1932        2  2020      4    80424
# 6     1935        4  2017      3    30554
# 7     1959        2  2013      3  1675149
# 8     1975        2  2020      3   101829
# 9     1976        3  2020      4    66740
# 10    1979        2  2020      4   310158
# 11    1982        3  2020      4     4962
# 12    1985        4  2020      4    63908
# 13    1987        1  2020      4    12927
# 14    1991        2  2020      4    18230
# 15    1991        2  2020      4  1744489
# 16    1997        1  2020      4   200406
# 17    1997        1  2020      4   104169
# 18    1997        1  2009      2   831001
# 19    1997        1  2013      3    47217
# 20    1999        4  2020      4   354950
# 21    1999        4  2020      4    50863
# 22    1999        4  2020      4   789019
# 23    1999        4  2015      1   732717
# 24    2001        1  2020      4    19617
# 25    2004        2  2020      4   732712
# 26    2004        2  2020      3    78003
# 27    2008        1  2020      4    93410
# 28    2008        1  2013      3    70858
# 29    2008        3  2012      3  1103982
# 30    2009        2  2020      4   858877
# 31    2009        2  2020      4    86312
# 32    2012        3  2020      4   731766
# 33    2013        3  2020      4   320187
# 34    2013        3  2020      4   886982
# 35    2013        3  2020      4  1403161
# 36    2015        1  2020      4   320193
# 37    2017        3  2019      2  1666700
# 38    2018        2  2020      4  1618921
# 39    2019        2  2020      4  1751788
